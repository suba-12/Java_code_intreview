# %%
if 5 > 6 :
    print("5 is greater")
else:
    print("5 is less")
# Out:
# 5 is less

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = str(3)
y = int(3)
z = float(3)
print(x ,y,z)
# Out:
# 3 3 3.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "John"
# is the same as
x = 'John'
print(x,x)
# Out:
# John John

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a,A)
# Out:
# 4 Sally

# %%
MyVariableName = "John"
print(MyVariableName)
# Out:
# John

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# LIST

# %%
fruite = ["apple","banana","cherry"]
print(fruite)
x,y,z = fruite
print(x)
print(y)
print(z)
# Out:
# ['apple', 'banana', 'cherry']
# apple
# banana
# cherry

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x=5
y=10
print(x+y)
# Out:
# 15

# %%
x = "awesome"
def myfunc():
    print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
'''
Text Type:	str
Numeric Types:	int, float, complex
Sequence Types:	list, tuple, range
Mapping Type:	dict
Set Types:	set, frozenset
Boolean Type:	bool
Binary Types:	bytes, bytearray, memoryview
None Type:	NoneType

'''

# %%
'''
x = ["apple", "banana", "cherry"]	list	
x = ("apple", "banana", "cherry")	tuple
x = {"name" : "John", "age" : 36}	dict	
x = {"apple", "banana", "cherry"}	set

'''

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
a = "Hello, World!"
print(a[1])
print(len(a))
# Out:
# e
# 13

# %%
for i in "banana":
    print(i)
# Out:
# b
# a
# n
# a
# n
# a

# %%
txt = "The best things in life are free!"
print("free" in txt)

if "free" in txt:
    print("yes,'free' is present " )

if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# True
# yes,'free' is present
# No, 'expensive' is NOT present.

# %%
b = "hello , world"
print(b[2:5])
print(b[:5])
print(b[-1])
print(b[2:])
print(b[-5:-2])
print(b.lower())
print(b.upper())
print(b.strip())
print(b.replace("h","s"))
print(b.split(","))
# Out:
# llo
# hello
# d
# llo , world
# wor
# hello , world
# HELLO , WORLD
# hello , world
# sello , world
# ['hello ', ' world']

# %%
a = "Hello"
b = "World"
c = a +" "+ b
print(c)
# Out:
# HelloWorld

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
'''\'	Single Quote	
\\	Backslash	
\n	New Line	
\r	Carriage Return	
\t	Tab	
\b	Backspace	
\f	Form Feed	
\ooo	Octal value	
\xhh	Hex value'''

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
bool("abc")
bool(123)
bool(["apple", "cherry", "banana"])
# Out:
# True

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
def myFunction() :
  return True

print(myFunction())
# Out:
# True

# %%
x = 200
print(isinstance(x, int))
# Out:
# True

# %%
print(float(10/2))
print(int(10%2))
print(f"{10/2:.3f}")
print(10//11)
# Out:
# 5.0
# 0
# 5.000
# 0

# %% [markdown]
# 1) PYTHON LIST
# 2) ORDERED
# 3) CHANGEABLE
# 4) ALLOW DUPLICATES
# 5) DATA TYPES - STRING ,INT , BOOLEAN AND ALSO CONTAIN ["abc", 34, True, 40, "male"]
# 6) TYPE() -> <class 'list'>

# %%
mylist = ["apple","banana","cherry"]
print(mylist)
print(len(mylist))
print(mylist[-1])
print(mylist[1])
print(mylist[0:3])
# Out:
# ['apple', 'banana', 'cherry']
# 3
# cherry
# banana
# ['apple', 'banana', 'cherry']

# %%
for i in mylist:
    print(i)
# Out:
# apple
# banana
# cherry

# %%
if "apple" in mylist:
    print("yes")
# Out:
# yes

# %%
mylist[1]="Govoa"
print(mylist)
# Out:
# ['apple', 'Govoa', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:4] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist.insert(1,"orange")
print(thislist)
# Out:
# ['apple', 'orange', 'orange', 'banana', 'cherry', 'orange']

# %%
#extend list
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']
# ['apple', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'papaya']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
mylist=["apple","banana","cherry"]
for i in range(len(mylist)):
    print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
  print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
thislist = ["apple", "banana", "cherry"]
newlist = []
for x in thislist:
    if 'a' in x :
        newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana']

# %%
newlist = [x for x in newlist if x != "apple"]
print(newlist)
# Out:
# ['banana']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
for x in list2:
    list1.append(x)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# TUPLE
#
# 1) ORDERED
# 2) UNCHANGEABLE
# 3) ALLOW DUPLICATE VALUES

# %%
thistuple = ("apple","baanana","cherry")
print(thistuple)
# Out:
# ('apple', 'baanana', 'cherry')

# %%
thistuple = ("apple","baanana","cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)
print(tuple1 + tuple2 + tuple3)
# Out:
# ('apple', 'banana', 'cherry', 1, 5, 7, 9, 3, True, False, False)

# %%
#covert tuple into list then change

x = ("apple", "banana", "cherry")
y=list(x)
y[1]="kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
#Add tuple to a tuple. You are allowed to add tuples to tuples
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
#If the number of variables is less than the number of values, you can add an * 

fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
numbers = list(map(int, input("Enter numbers separated by space: ").split()))
print("List of numbers:", numbers)
# Out:
# List of numbers: [2, 3, 4, 5]

# %%
salary = input("Enter your salary: ")
print(salary)
# Out:
# hi

# %%
age = int(input())
print(age)
# Out:
# 23

# %% [markdown]
# INPUT

# %%
#STRING
arr = input("enter the elements").split()
print(arr)
# Out:
# ['suba', 'a', 's']

# %%
arr = list(map(int,input("enter teh elements").split()))
print(arr)
# Out:
# [3, 5, 2]

# %%
# taking comma for inputs
arr = input("enater").split(",")
#covert into integer
arr =[int(x) for x in arr]
print(arr)
# Out:
# [3, 6, 5, 7]

# %%
n = int(input("Enter number of elements: "))
arr = [input(f"Enter element {i+1}: ") for i in range(n)]
print("Array:", arr)
# Out:
# Array: ['a', 'b', 'a']

# %%
a = 10
b = 5
print(a ** b % 3 )
# Out:
# 1

# %%
a = 27
b = 3
c = 4
r = a + b * c // ( c % b ) - 5
print( r)
# Out:
# 22

# %%
print(a//b)
# Out:
# 5

# %%
print(27/2**2)
# Out:
# 6.75

# %%
import keyword
print(len(keyword.kwlist))
print(keyword.kwlist)
# Out:
# 35
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
me = "It's a string"
print(me)
# Out:
# It's a string

# %%
me = '"Beautiful is better than ugly.". Said Tim Peters'
print(me)
# Out:
# "Beautiful is better than ugly.". Said Tim Peters

# %%
me = 'It\'s also a valid string'
print(me)
# Out:
# It's also a valid string

# %%
name = 'John'
message = f'Hi {name}'
print(message)
# Out:
# Hi John

# %%
greeting = 'Good ' 'Morning!'
print(greeting)
# Out:
# Good Morning!

# %% [markdown]
# strings are immutable
# But if you want to modify it storing another variable

# %%
p = 1000
i = 0.05
y = 2
a = p *(1+i) ** y
print(f"Total amount : ${a:,.2f}")
print(f"Total amount : ${a:.2f}")
# Out:
# Total amount : $1,102.50
# Total amount : $1102.50

# %%
n = 100
sum = n * (n+1)/2
print(int(sum))
# Out:
# 5050

# %% [markdown]
#  Using the Python while statement to build a simple command prompt program

# %%
command = ''

while command.lower() != 'quit':
    command = input('>')
    print(f"Echo: {command}")
# Out:
# Echo: hi
# Echo: quit

# %%
# Out:
# Echo: hi
# Echo: hello
# Echo: quit

# %%
for i in range(1,100):
    pass
